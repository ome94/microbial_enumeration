# %% [markdown]
# #

# %%
import numpy as np
import pandas as pd
from scipy import stats

import matplotlib.pyplot as plt
import seaborn as sns

import pingouin

# %%
control = pd.read_excel('microbial enumeration.xlsx')
week_1 = pd.read_excel('microbial enumeration.xlsx', sheet_name='wk1_experiment')
week_4 = pd.read_excel('microbial enumeration.xlsx', sheet_name='wk4_experiment')
# Out:
# C:\Users\Emmanuel\miniconda3\envs\analysis\Lib\site-packages\outdated\utils.py:14: OutdatedPackageWarning: The package pingouin is out of date. Your version is 0.5.3, the latest is 0.5.5.
# Set the environment variable OUTDATED_IGNORE=1 to disable these warnings.
#   return warn(

# %%
control
# Out:
#    Sample Code  TVC_r  TVC_l  TCC_r  TCC_l  TFC_r  TFC_l
# 0           B1     15     17      0      0      3      2
# 1           B2     11      8      0      0      2      2
# 2           B3      0      0      0      0      0      0
# 3           B4      4      5      0      0      0      0
# 4           B5      7      5      0      0      0      0
# 5           B6      0      0      0      0      2      1
# 6           B7      5      7      0      0      0      0
# 7           B9     12     10      0      0      1      0
# 8          B11      0      0      0      0      0      0
# 9          B12      5      5      0      0      0      0
# 10         B13      7      4      0      0      2      2
# 11         B14      0      0      0      0      0      0
# 12         B15      2      3      0      0      0      0
# 13         B16     13     10      0      0      0      0
# 14         B17     11      8      0      0      3      3
# ...

# %%
week_1
# Out:
#    Sample Code  TVC_r  TVC_l  TCC_r  TCC_l  TFC_r  TFC_l
# 0           S1     27     32      0      0      5      3
# 1           S2     21     25      0      0      2      2
# 2           S3     13     11      0      0      4      3
# 3           S4      5      7      0      0      1      2
# 4           S5     15     17      0      0      2      3
# 5           S6      8     10      0      0      5      3
# 6           S8     23     18      0      0      5      5
# 7           S9     12     10      0      0      2      1
# 8          S10      8     11      0      0      3      3
# 9          S11     15     17      0      0      2      2
# 10         S13      5      7      0      0      4      3
# 11         S14      8     10      0      0      2      3
# 12         S15      3      3      0      0      4      3
# 13         S16     10      7      0      0      2      2
# 14         S17     11     13      0      0      5      4
# ...

# %%
week_4
# Out:
#    Sample Code  TVC_r  TVC_l  TCC_r  TCC_l  TFC_r  TFC_l
# 0           B1     38     35      0      0      8      6
# 1           B2     27     31      0      0      7      5
# 2           B3     22     27      0      0     10      8
# 3           B4     11     13      0      0      3      3
# 4           B5     23     27      0      0      5      7
# 5           B6     17     21      0      0     11      9
# 6           B8     35     32      0      0      7      5
# 7           B9     27     24      0      0      4      5
# 8          B10     10     13      0      0      8      6
# 9          B11     28     25      0      0      5      3
# 10         B13     11      9      0      0      4      5
# 11         B14     15     18      0      0      3      5
# 12         B15     10      8      0      0      2      3
# 13         B16     13     17      0      0      3      3
# 14         B17     11     13      0      0      3      2
# ...

# %%
control['Sample Code'] = control['Sample Code'].str.replace('B', 'S').str.strip()
control
# Out:
#    Sample Code  TVC_r  TVC_l  TCC_r  TCC_l  TFC_r  TFC_l
# 0           S1     15     17      0      0      3      2
# 1           S2     11      8      0      0      2      2
# 2           S3      0      0      0      0      0      0
# 3           S4      4      5      0      0      0      0
# 4           S5      7      5      0      0      0      0
# 5           S6      0      0      0      0      2      1
# 6           S7      5      7      0      0      0      0
# 7           S9     12     10      0      0      1      0
# 8          S11      0      0      0      0      0      0
# 9          S12      5      5      0      0      0      0
# 10         S13      7      4      0      0      2      2
# 11         S14      0      0      0      0      0      0
# 12         S15      2      3      0      0      0      0
# 13         S16     13     10      0      0      0      0
# 14         S17     11      8      0      0      3      3
# ...

# %%
week_4['Sample Code'] = week_4['Sample Code'].str.replace('B', 'S').str.strip()
week_4
# Out:
#    Sample Code  TVC_r  TVC_l  TCC_r  TCC_l  TFC_r  TFC_l
# 0           S1     38     35      0      0      8      6
# 1           S2     27     31      0      0      7      5
# 2           S3     22     27      0      0     10      8
# 3           S4     11     13      0      0      3      3
# 4           S5     23     27      0      0      5      7
# 5           S6     17     21      0      0     11      9
# 6           S8     35     32      0      0      7      5
# 7           S9     27     24      0      0      4      5
# 8          S10     10     13      0      0      8      6
# 9          S11     28     25      0      0      5      3
# 10         S13     11      9      0      0      4      5
# 11         S14     15     18      0      0      3      5
# 12         S15     10      8      0      0      2      3
# 13         S16     13     17      0      0      3      3
# 14         S17     11     13      0      0      3      2
# ...

# %%
control['TVC_total'] = control['TVC_r'] + control['TVC_l']
control['TFC_total'] = control['TFC_r'] + control['TFC_l']
control
# Out:
#    Sample Code  TVC_r  TVC_l  TCC_r  TCC_l  TFC_r  TFC_l  TVC_total  TFC_total
# 0           S1     15     17      0      0      3      2         32          5
# 1           S2     11      8      0      0      2      2         19          4
# 2           S3      0      0      0      0      0      0          0          0
# 3           S4      4      5      0      0      0      0          9          0
# 4           S5      7      5      0      0      0      0         12          0
# 5           S6      0      0      0      0      2      1          0          3
# 6           S7      5      7      0      0      0      0         12          0
# 7           S9     12     10      0      0      1      0         22          1
# 8          S11      0      0      0      0      0      0          0          0
# 9          S12      5      5      0      0      0      0         10          0
# 10         S13      7      4      0      0      2      2         11          4
# ...

# %%
week_1['TVC_total'] = week_1['TVC_r'] + week_1['TVC_l']
week_1['TFC_total'] = week_1['TFC_r'] + week_1['TFC_l']
week_1
# Out:
#    Sample Code  TVC_r  TVC_l  TCC_r  TCC_l  TFC_r  TFC_l  TVC_total  TFC_total
# 0           S1     27     32      0      0      5      3         59          8
# 1           S2     21     25      0      0      2      2         46          4
# 2           S3     13     11      0      0      4      3         24          7
# 3           S4      5      7      0      0      1      2         12          3
# 4           S5     15     17      0      0      2      3         32          5
# 5           S6      8     10      0      0      5      3         18          8
# 6           S8     23     18      0      0      5      5         41         10
# 7           S9     12     10      0      0      2      1         22          3
# 8          S10      8     11      0      0      3      3         19          6
# 9          S11     15     17      0      0      2      2         32          4
# 10         S13      5      7      0      0      4      3         12          7
# ...

# %%
week_4['TVC_total'] = week_4['TVC_r'] + week_4['TVC_l']
week_4['TFC_total'] = week_4['TFC_r'] + week_4['TFC_l']
week_4
# Out:
#    Sample Code  TVC_r  TVC_l  TCC_r  TCC_l  TFC_r  TFC_l  TVC_total  TFC_total
# 0           S1     38     35      0      0      8      6         73         14
# 1           S2     27     31      0      0      7      5         58         12
# 2           S3     22     27      0      0     10      8         49         18
# 3           S4     11     13      0      0      3      3         24          6
# 4           S5     23     27      0      0      5      7         50         12
# 5           S6     17     21      0      0     11      9         38         20
# 6           S8     35     32      0      0      7      5         67         12
# 7           S9     27     24      0      0      4      5         51          9
# 8          S10     10     13      0      0      8      6         23         14
# 9          S11     28     25      0      0      5      3         53          8
# 10         S13     11      9      0      0      4      5         20          9
# ...

# %%
control = control[(control['TVC_total']>= 7) & (control['TVC_total'] <= 23)]

control
# Out:
#    Sample Code  TVC_r  TVC_l  TCC_r  TCC_l  TFC_r  TFC_l  TVC_total  TFC_total
# 1           S2     11      8      0      0      2      2         19          4
# 3           S4      4      5      0      0      0      0          9          0
# 4           S5      7      5      0      0      0      0         12          0
# 6           S7      5      7      0      0      0      0         12          0
# 7           S9     12     10      0      0      1      0         22          1
# 9          S12      5      5      0      0      0      0         10          0
# 10         S13      7      4      0      0      2      2         11          4
# 13         S16     13     10      0      0      0      0         23          0
# 14         S17     11      8      0      0      3      3         19          6
# 15         S18      7      9      0      0      0      0         16          0
# 17         S20      6      5      0      0      0      0         11          0

# %%
control['week'] = 0

control
# Out:
# C:\Users\Emmanuel\AppData\Local\Temp\ipykernel_10216\1623811030.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   control['week'] = 0
#    Sample Code  TVC_r  TVC_l  TCC_r  TCC_l  TFC_r  TFC_l  TVC_total  \
# 1           S2     11      8      0      0      2      2         19
# 3           S4      4      5      0      0      0      0          9
# 4           S5      7      5      0      0      0      0         12
# 6           S7      5      7      0      0      0      0         12
# 7           S9     12     10      0      0      1      0         22
# 9          S12      5      5      0      0      0      0         10
# 10         S13      7      4      0      0      2      2         11
# ...

# %%
week_1 = week_1[week_1['Sample Code'].isin(control['Sample Code'])]
week_1['week'] = 1

week_1
# Out:
# C:\Users\Emmanuel\AppData\Local\Temp\ipykernel_10216\423679915.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   week_1['week'] = 1
#    Sample Code  TVC_r  TVC_l  TCC_r  TCC_l  TFC_r  TFC_l  TVC_total  \
# 1           S2     21     25      0      0      2      2         46
# 3           S4      5      7      0      0      1      2         12
# 4           S5     15     17      0      0      2      3         32
# 7           S9     12     10      0      0      2      1         22
# 10         S13      5      7      0      0      4      3         12
# 13         S16     10      7      0      0      2      2         17
# 14         S17     11     13      0      0      5      4         24
# ...

# %%
week_4 = week_4[week_4['Sample Code'].isin(control['Sample Code'])]
week_4['week'] = 4

week_4
# Out:
# C:\Users\Emmanuel\AppData\Local\Temp\ipykernel_10216\3130772014.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   week_4['week'] = 4
#    Sample Code  TVC_r  TVC_l  TCC_r  TCC_l  TFC_r  TFC_l  TVC_total  \
# 1           S2     27     31      0      0      7      5         58
# 3           S4     11     13      0      0      3      3         24
# 4           S5     23     27      0      0      5      7         50
# 7           S9     27     24      0      0      4      5         51
# 10         S13     11      9      0      0      4      5         20
# 13         S16     13     17      0      0      3      3         30
# 14         S17     11     13      0      0      3      2         24
# ...

# %%
samples = set(control["Sample Code"]).intersection(set(week_1["Sample Code"])).intersection(set(week_4["Sample Code"]))

# %%
data = control[['Sample Code', 'TVC_total', 'TFC_total']]\
        .merge(week_1[['Sample Code', 'TVC_total', 'TFC_total']], on='Sample Code', suffixes=('', '_wk1'))\
        .merge(week_4[['Sample Code', 'TVC_total', 'TFC_total']], on='Sample Code', suffixes=('', '_wk4'))

data
# Out:
#   Sample Code  TVC_total  TFC_total  TVC_total_wk1  TFC_total_wk1  \
# 0          S2         19          4             46              4
# 1          S4          9          0             12              3
# 2          S5         12          0             32              5
# 3          S9         22          1             22              3
# 4         S13         11          4             12              7
# 5         S16         23          0             17              4
# 6         S17         19          6             24              9
# 7         S18         16          0             12              7
#
#    TVC_total_wk4  TFC_total_wk4
# 0             58             12
# 1             24              6
# 2             50             12
# 3             51              9
# 4             20              9
# 5             30              6
# 6             24              5
# 7             26              7

# %%
filter_samples = lambda df: df.loc[df["Sample Code"].isin(samples)]
combined_set = pd.concat([filter_samples(df) for df in (control, week_1, week_4)], ignore_index=True)

combined_set
# Out:
#    Sample Code  TVC_r  TVC_l  TCC_r  TCC_l  TFC_r  TFC_l  TVC_total  \
# 0           S2     11      8      0      0      2      2         19
# 1           S4      4      5      0      0      0      0          9
# 2           S5      7      5      0      0      0      0         12
# 3           S9     12     10      0      0      1      0         22
# 4          S13      7      4      0      0      2      2         11
# 5          S16     13     10      0      0      0      0         23
# 6          S17     11      8      0      0      3      3         19
# 7          S18      7      9      0      0      0      0         16
# 8           S2     21     25      0      0      2      2         46
# 9           S4      5      7      0      0      1      2         12
# 10          S5     15     17      0      0      2      3         32
# 11          S9     12     10      0      0      2      1         22
# 12         S13      5      7      0      0      4      3         12
# ...

# %%
sns.relplot(data=combined_set, x="week", y="TVC_total");
plt.xticks([0, 1, 4]);
plt.title("Observed Individual TVC");

# %%
sns.relplot(data=combined_set, x="week", y="TFC_total");
plt.xticks([0, 1, 4]);
plt.title("Observed Individual TFC");

# %%
sns.catplot(data=combined_set, x="week", y="TVC_total", kind="point");
plt.title("Weekly Average TVC Total");

# %%
sns.catplot(data=combined_set, x="week", y="TFC_total", kind="point");
plt.title("Weekly Average TFC Total");

# %%
bins = np.arange(0, combined_set["TVC_total"].max()+3, 3)
sns.histplot(data=combined_set, x="TVC_total", hue="week", alpha=0.25, bins=bins, palette={0: "blue", 1:"red", 4: "green"});

# %%
grid = sns.FacetGrid(data=combined_set, col="week", height=4, aspect=1)
grid.map(plt.hist, "TVC_total", bins=bins)
grid.fig.suptitle("TVC Total Distribution", y=1);

# %%
grid = sns.FacetGrid(data=combined_set, row="week", sharex=False, height=3.5, aspect=1)
grid.map(plt.hist, "TVC_total", bins=bins)
grid.fig.suptitle("TVC Total Distribution", y=1);

# %%
bins = np.arange(0, combined_set["TFC_total"].max()+3, 2)
sns.histplot(data=combined_set, x="TFC_total", hue="week", alpha=0.25, bins=bins, palette={0: "blue", 1:"red", 4: "green"});

# %%
grid = sns.FacetGrid(data=combined_set, col="week", sharex=False, height=4, aspect=1)
grid.map(plt.hist, "TFC_total", bins=bins)
grid.fig.suptitle("TFC Total Distribution", y=1, fontsize=12);

# %%
grid = sns.FacetGrid(data=combined_set, row="week", sharex=False, height=3.5, aspect=1)
grid.map(plt.hist, "TFC_total", bins=bins)
grid.fig.suptitle("TFC Total Distribution", y=1, fontsize=10);

# %%
data['wk1_diff'] = data.TVC_total_wk1 - data.TVC_total
data['wk4_diff'] = data.TVC_total_wk4 - data.TVC_total

data
# Out:
#   Sample Code  TVC_total  TFC_total  TVC_total_wk1  TFC_total_wk1  \
# 0          S2         19          4             46              4
# 1          S4          9          0             12              3
# 2          S5         12          0             32              5
# 3          S9         22          1             22              3
# 4         S13         11          4             12              7
# 5         S16         23          0             17              4
# 6         S17         19          6             24              9
# 7         S18         16          0             12              7
#
#    TVC_total_wk4  TFC_total_wk4  wk1_diff  wk4_diff
# 0             58             12        27        39
# 1             24              6         3        15
# 2             50             12        20        38
# 3             51              9         0        29
# 4             20              9         1         9
# 5             30              6        -6         7
# ...

# %%
plt.hist(data.wk1_diff);

# %%
plt.hist(data.wk4_diff);

# %%
np.random.seed(10)

bootstrap_dist = []

for _ in range(10000):
    sample = data.wk1_diff.sample(frac=1, replace=True)
    bootstrap_dist.append(sample.mean())
    
np.mean(bootstrap_dist)
# Out:
# 5.727125

# %%
plt.hist(bootstrap_dist);

# %%
np.quantile(bootstrap_dist, 0.025), np.quantile(bootstrap_dist, 0.975)
# Out:
# (-1.125, 13.75)

# %%
np.std(bootstrap_dist, ddof=1)
# Out:
# 3.886768411063762

# %%
pingouin.ttest(x=data['TVC_total_wk1'],
               y=data['TVC_total'],
               paired=True,
               alternative='two-sided')
# Out:
#                T  dof alternative     p-val         CI95%   cohen-d   BF10  \
# T-test  1.394946    7   two-sided  0.205695  [-4.0, 15.5]  0.621914  0.696
#
#            power
# T-test  0.330679

# %%
pingouin.ttest(x=data['TFC_total_wk1'],
               y=data['TFC_total'],
               paired=True,
               alternative='two-sided')
# Out:
#                T  dof alternative     p-val        CI95%   cohen-d    BF10  \
# T-test  4.620764    7   two-sided  0.002424  [1.65, 5.1]  1.464281  20.148
#
#            power
# T-test  0.941814

# %%
pingouin.ttest(x=data['TVC_total_wk4'],
               y=data['TVC_total'],
               paired=True,
               alternative='two-sided')
# Out:
#                T  dof alternative     p-val          CI95%   cohen-d   BF10  \
# T-test  3.802717    7   two-sided  0.006691  [7.19, 30.81]  1.687996  8.963
#
#            power
# T-test  0.981897

# %%
pingouin.ttest(x=data['TFC_total_wk4'],
               y=data['TFC_total'],
               paired=True,
               alternative='two-sided')
# Out:
#                T  dof alternative     p-val         CI95%   cohen-d    BF10  \
# T-test  4.923787    7   two-sided  0.001706  [3.31, 9.44]  2.481801  26.736
#
#            power
# T-test  0.999957
